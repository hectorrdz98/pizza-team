# %%
import pandas as pd

# %%
# Load of all .csv
# df_ubereats_centro = pd.read_csv(r'csv/ubereats-pizza-centro.csv')
# df_ubereats_alamos = pd.read_csv(r'csv/ubereats-pizza-alamos.csv')
# df_ubereats_juriquilla = pd.read_csv(r'csv/ubereats-pizza-juriquilla.csv')
# df_ubereats_milenio = pd.read_csv(r'csv/ubereats-pizza-milenio.csv')
# df_ubereats_refugio = pd.read_csv(r'csv/ubereats-pizza-refugio.csv')

df_ubereats_balvanera = pd.read_csv(r'csv/ubereats-pizza-balvanera.csv')
# df_ubereats_campanario = pd.read_csv(r'csv/ubereats-pizza-campanario.csv')
# df_ubereats_cerritocolorado = pd.read_csv(r'csv/ubereats-pizza-cerritocolorado.csv')
# df_ubereats_cimatario = pd.read_csv(r'csv/ubereats-pizza-cimatario.csv')
# df_ubereats_el_pueblito = pd.read_csv(r'csv/ubereats-pizza-el-pueblito.csv')

# df_rappi_centro = pd.read_csv(r'csv/rappi-pizza-centro.csv')
# df_rappi_alamos = pd.read_csv(r'csv/rappi-pizza-alamos.csv')
# df_rappi_juriquilla = pd.read_csv(r'csv/rappi-pizza-juriquilla.csv')
# df_rappi_milenio = pd.read_csv(r'csv/rappi-pizza-milenio.csv')
# df_rappi_refugio = pd.read_csv(r'csv/rappi-pizza-refugio.csv')

# df_rappi_balvanera = pd.read_csv(r'csv/rappi-pizza-balvanera.csv')
# df_rappi_campanario = pd.read_csv(r'csv/rappi-pizza-campanario.csv')
# df_rappi_cerritocolorado = pd.read_csv(r'csv/rappi-pizza-cerritocolorado.csv')
df_rappi_cimatario = pd.read_csv(r'csv/rappi-pizza-cimatario.csv')
# df_rappi_el_pueblito = pd.read_csv(r'csv/rappi-pizza-el-pueblito.csv')

frames = [
    # df_ubereats_centro, 
    # df_ubereats_alamos, 
    # df_ubereats_juriquilla, 
    # df_ubereats_milenio, 
    # df_ubereats_refugio, 
    df_ubereats_balvanera, 
    # df_ubereats_campanario, 
    # df_ubereats_cerritocolorado, 
    # df_ubereats_cimatario, 
    # df_ubereats_el_pueblito, 
    # df_rappi_centro, 
    # df_rappi_alamos, 
    # df_rappi_juriquilla, 
    # df_rappi_milenio, 
    # df_rappi_refugio, 
    # df_rappi_balvanera, 
    # df_rappi_campanario, 
    # df_rappi_cerritocolorado, 
    df_rappi_cimatario] 
    # df_rappi_el_pueblito]

# We concat all frames and ignore the current index to generate a new one
df = pd.concat(frames, ignore_index=True)

# %%
print('Size of the df: {} items'.format(df.count()['name']))
# Out:
# Size of the df: 2402 items

# %%
# Note that the price-food has MX$
df.loc[:,['name','rating','evals','name-food','price-food']]
# Out:
#                              name  rating  evals  \
# 0     El Globo Citadina Querétaro     4.8  (497)
# 1                Piacere Italiano     4.4   (99)
# 2                    Monkey Asado     3.8   (15)
# 3          La Campana Café Bistro     NaN    NaN
# 4                    Monkey Asado     3.8   (15)
# ...                           ...     ...    ...
# 2399                     Diktatur     4.3    NaN
# 2400                 Brutus Pizza     4.8    NaN
# 2401                      Pizzeta     4.5    NaN
# 2402            La Vieja Varsovia     NaN    NaN
# 2403               Tonino's Pizza     4.8    NaN
#
#                           name-food price-food
# 0                Pastel Carrot Cake   MX$46.00
# 1                    Insalata Greca  MX$155.00
# 2                        Papas gajo   MX$80.00
# 3                          Malteada   MX$84.00
# 4                Hamburguesa master  MX$150.00
# ...                             ...        ...
# 2399          Agua de Pepino 450 ml         50
# 2400                 Pizza Hawaiana        189
# 2401  Helado Solero Paradise Frutos         32
# 2402             Tocino Champiñones        138
# 2403      Jarra de Naranjada Grande         92
#
# [2404 rows x 5 columns]

# %%
# Remove MX$ from price-food
df['price-food'] = df['price-food'].apply(lambda x: float(x[3:]) if not isinstance(x, float) else x)

# for index, row in df.iterrows():
#     print(float(row['price-food'][3:]) if not isinstance(row['price-food'], float) else row['price-food'])

# %%
df.loc[:,['name','name-food','price-food']]
# Out:
#                              name                      name-food  price-food
# 0     El Globo Citadina Querétaro             Pastel Carrot Cake        46.0
# 1                Piacere Italiano                 Insalata Greca       155.0
# 2                    Monkey Asado                     Papas gajo        80.0
# 3          La Campana Café Bistro                       Malteada        84.0
# 4                    Monkey Asado             Hamburguesa master       150.0
# ...                           ...                            ...         ...
# 2399                     Diktatur          Agua de Pepino 450 ml        50.0
# 2400                 Brutus Pizza                 Pizza Hawaiana       189.0
# 2401                      Pizzeta  Helado Solero Paradise Frutos        32.0
# 2402            La Vieja Varsovia             Tocino Champiñones       138.0
# 2403               Tonino's Pizza      Jarra de Naranjada Grande        92.0
#
# [2404 rows x 3 columns]

# %%
# Get all "pizza" dataframes
dfPizzas = df[df['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas.reset_index(drop=True, inplace=True)
dfPizzas.loc[:,['name','name-food','price-food']]
# Out:
#                             name                              name-food  \
# 0                 PANDINIS PIZZA  Pizza Hawaiana Especial Tamaño Grande
# 1          La neta alas y chelas                         Pizza boloñesa
# 2                  Pizza Rotonda                Pizza especial tropical
# 3    Benedetti's Pizza Amsterdam             Pizza Mediana Especialidad
# 4                 PANDINIS PIZZA             Pizza Básica Tamaño Grande
# ..                           ...                                    ...
# 546               Tonino's Pizza                      Pizza Vegetariana
# 547           Trattoria La Nonna                      Pizza Vegetariana
# 548                    Pizza Tec                         Pizza Hawaiana
# 549                     Diktatur                        Pizza Monsiváis
# 550                 Brutus Pizza                         Pizza Hawaiana
#
#      price-food
# 0         198.0
# 1         195.0
# 2         129.0
# 3         238.0
# 4         129.0
# ..          ...
# 546       208.0
# 547       165.0
# 548        84.0
# 549        50.0
# 550       189.0
#
# [551 rows x 3 columns]

# %%
minPizza = dfPizzas.loc[dfPizzas['price-food'] == dfPizzas['price-food'].min()]

print('The pizzas with the lower price are:')
minPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the lower price are:
#          name           name-food  price-food
# 220  Diktatur   Pizza Vegetariana        50.0
# 225  Diktatur        Pizza Verona        50.0
# 241  Diktatur         Pizza Muzza        50.0
# 338  Diktatur        Pizza Vegana        50.0
# 382  Diktatur      Pizza Caribeña        50.0
# 394  Diktatur          Pizza Miel        50.0
# 463  Diktatur   Pizza Franz Kafka        50.0
# 477  Diktatur           Pizza Bbq        50.0
# 488  Diktatur      Pizza Granjero        50.0
# 518  Diktatur  Pizza Metamorfosis        50.0
# 528  Diktatur         Pizza Sarte        50.0
# 549  Diktatur     Pizza Monsiváis        50.0

# %%
maxPizza = dfPizzas.loc[dfPizzas['price-food'] == dfPizzas['price-food'].max()]

print('The pizzas with the greatest price are:')
maxPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the greatest price are:
#               name      name-food  price-food
# 448  Santa Fortuna  Pizza & Pasta       435.0

# %%
meanPizzaVal = dfPizzas['price-food'].mean()
meanPizza = dfPizzas.loc[dfPizzas['price-food'] == meanPizzaVal]

print(f'The mean price is ${meanPizzaVal}:')
meanPizza.loc[:,['name','name-food','price-food']]
# Out:
# The mean price is $180.3045372050817:
# Empty DataFrame
# Columns: [name, name-food, price-food]
# Index: []

# %%
medianPizza = dfPizzas.loc[dfPizzas['price-food'] == dfPizzas['price-food'].median()]

print('The pizzas with the median price are:')
medianPizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the median price are:
#                         name                  name-food  price-food
# 12          Piacere Italiano          Pizza Capricciosa       175.0
# 41          Piacere Italiano            Pizza La Nostra       175.0
# 42          Piacere Italiano              Pizza Rústica       175.0
# 64          Piacere Italiano              Pizza Gustosa       175.0
# 89          Piacere Italiano              Pizza Rústica       175.0
# 102  Los Dogos (Puerta Real)               Pizza Burger       175.0
# 258        La Piccola Italia          Pizza Viuda Negra       175.0
# 298         Piacere Italiano          Pizza Capricciosa       175.0
# 308        La Piccola Italia  Pizza Calzone Champiñones       175.0
# 330                Piu Pizza   Pizza con Frutos del Mar       175.0
# 356        La Piccola Italia    Pizza La Piccola Italia       175.0

# %%
modePizza = dfPizzas.loc[dfPizzas['price-food'] == dfPizzas['price-food'].mode()[0]]

print('The pizzas with the mode price are:')
modePizza.loc[:,['name','name-food','price-food']]
# Out:
# The pizzas with the mode price are:
#                  name                 name-food  price-food
# 6    Piacere Italiano    Pizza Prosciutto Cotto       150.0
# 37   Piacere Italiano              Pizza Funghi       150.0
# 90   Piacere Italiano    Pizza Quattro Formaggi       150.0
# 146     Trapani Pizza              Pizza Pastor       150.0
# 147        Che Chelas        Pizza Carnes Frías       150.0
# 155     Trapani Pizza         Pizza Vegetariana       150.0
# 194     Trapani Pizza  Pizza Pepperoni Especial       150.0
# 208     Trapani Pizza             Pizza Norteña       150.0
# 210     Trapani Pizza            Pizza Hawaiana       150.0
# 211     Trapani Pizza              Pizza Típica       150.0
# 248     Trapani Pizza        Pizza Carnes Frías       150.0
# 262  Piacere Italiano              Pizza Funghi       150.0
# 293        Che Chelas            Pizza Hawaiana       150.0
# 311     Trapani Pizza             Pizza Paraíso       150.0
# 337        Che Chelas           Pizza Margarita       150.0
# 363     Trapani Pizza             Pizza Suprema       150.0
# 376  Piacere Italiano    Pizza Quattro Formaggi       150.0
# 400     Trapani Pizza            Pizza Mexicana       150.0
# 425  Piacere Italiano    Pizza Prosciutto Cotto       150.0
# 432     Trapani Pizza           Pizza Carnívora       150.0
# 468     Trapani Pizza            Pizza Marinera       150.0
# 469        Che Chelas        Pizza de Pepperoni       150.0
# 505     Trapani Pizza          Pizza de la Casa       150.0
